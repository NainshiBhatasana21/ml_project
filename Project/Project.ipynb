# %%
import pandas as pd

# %%
# Read CSV File
df = pd.read_csv("insurance_fraud_data.csv")

# %%
# Display First 5 Records
df.head()
# Out:
#    claim_number  age_of_driver gender marital_status  safety_rating  \
# 0        414724             39      M              1             73
# 1        269568             33      M              1             72
# 2        974592             31      M              1             76
# 3        995328             53      F              1             93
# 4       1140480             41      M              1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_category vehicle_price vehicle_color  total_claim injury_claim  \
# ...

# %%
# Display Last 5 Records
df.tail()
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# 11997        66505.6               1               1            Rent
# 11998        23315.2               1               0            Rent
# 11999        66505.6               0               1             Own
# 12000        76409.6               1               0             Own
# 12001        70915.2               1               0            Rent
#
#        zip_code  ... vehicle_category vehicle_price vehicle_color  \
# ...

# %%
# Display Dataset Shape
df.shape
# Out:
# (12002, 29)

# %%
# Display Column Names
df.columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safety_rating', 'annual_income', 'high_education', 'address_change',
#        'property_status', 'zip_code', 'claim_date', 'claim_day_of_week',
#        'accident_site', 'past_num_of_claims', 'witness_present', 'liab_prct',
#        'channel', 'police_report', 'age_of_vehicle', 'vehicle_category',
#        'vehicle_price', 'vehicle_color', 'total_claim', 'injury_claim',
#        'policy deductible', 'annual premium', 'days open', 'form defects',
#        'fraud reported'],
#       dtype='object')

# %%
# Display Data Types
df.dtypes
# Out:
# claim_number            int64
# age_of_driver           int64
# gender                 object
# marital_status         object
# safety_rating           int64
# annual_income         float64
# high_education          int64
# address_change          int64
# property_status        object
# zip_code                int64
# claim_date             object
# claim_day_of_week      object
# accident_site          object
# past_num_of_claims      int64
# witness_present        object
# liab_prct               int64
# channel                object
# police_report           int64
# age_of_vehicle         object
# vehicle_category       object
# vehicle_price         float64
# vehicle_color          object
# total_claim           float64
# injury_claim           object
# policy deductible       int64
# annual premium        float64
# days open             float64
# form defects            int64
# fraud reported         object
# dtype: object

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12002 entries, 0 to 12001
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   claim_number        12002 non-null  int64
#  1   age_of_driver       12002 non-null  int64
#  2   gender              12002 non-null  object
#  3   marital_status      12002 non-null  object
#  4   safety_rating       12002 non-null  int64
#  5   annual_income       12002 non-null  float64
#  6   high_education      12002 non-null  int64
#  7   address_change      12002 non-null  int64
#  8   property_status     12002 non-null  object
#  9   zip_code            12002 non-null  int64
#  10  claim_date          12002 non-null  object
#  11  claim_day_of_week   12002 non-null  object
#  12  accident_site       12002 non-null  object
#  13  past_num_of_claims  12002 non-null  int64
#  14  witness_present     12002 non-null  object
# ...

# %%
df.describe()
# Out:
#        claim_number  age_of_driver  safety_rating  annual_income  \
# count  1.200200e+04   12002.000000   12002.000000   12002.000000
# mean   3.119801e+08      43.525162      73.702966   63658.226534
# std    1.795997e+08      12.201298      15.378967   17289.704559
# min    1.866240e+05      19.000000       2.000000      -1.600000
# 25%    1.561887e+08      35.000000      66.000000   56899.200000
# 50%    3.121908e+08      43.000000      76.000000   60899.200000
# 75%    4.677938e+08      51.000000      85.000000   64697.600000
# max    6.220385e+08     278.000000     100.000000  257313.600000
#
#        high_education  address_change      zip_code  past_num_of_claims  \
# count    12002.000000    12002.000000  12002.000000        12002.000000
# mean         0.698134        0.576737  49762.387269            0.494918
# std          0.459087        0.494097  29133.180765            0.956002
# min          0.000000        0.000000      0.000000            0.000000
# ...

# %%
df.describe(include='all')
# Out:
#         claim_number  age_of_driver gender marital_status  safety_rating  \
# count   1.200200e+04   12002.000000  12002          12002   12002.000000
# unique           NaN            NaN      2              3            NaN
# top              NaN            NaN      M              1            NaN
# freq             NaN            NaN   6216           8582            NaN
# mean    3.119801e+08      43.525162    NaN            NaN      73.702966
# std     1.795997e+08      12.201298    NaN            NaN      15.378967
# min     1.866240e+05      19.000000    NaN            NaN       2.000000
# 25%     1.561887e+08      35.000000    NaN            NaN      66.000000
# 50%     3.121908e+08      43.000000    NaN            NaN      76.000000
# 75%     4.677938e+08      51.000000    NaN            NaN      85.000000
# max     6.220385e+08     278.000000    NaN            NaN     100.000000
#
#         annual_income  high_education  address_change property_status  \
# ...

# %%
# Display One Column
df["vehicle_price"]
# Out:
# 0        24360.592730
# 1        23457.352820
# 2        19752.425230
# 3        32910.342240
# 4        28570.376750
#              ...
# 11997    24134.334750
# 11998    57417.739270
# 11999    20231.723630
# 12000    21900.031920
# 12001     8291.858346
# Name: vehicle_price, Length: 12002, dtype: float64

# %%
# Display First Row
df.shape[0]
# Out:
# 12002

# %%
# Display First Column
df.shape[1]
# Out:
# 29

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12002, step=1)

# %%
# random
df.sample(5)
# Out:
#       claim_number  age_of_driver gender marital_status  safety_rating  \
# 9983     429048576             54      F              1             89
# 3801     616149504             51      M              1             72
# 9714     400930560             36      M              0             88
# 6521      85805568             38      M              1             95
# 5535     587886336             28      M              0             34
#
#       annual_income  high_education  address_change property_status  zip_code  \
# 9983        63804.8               1               1             Own     15035
# 3801        62923.2               1               0            Rent     85017
# 9714        57344.0               0               1            Rent     85039
# 6521        58206.4               1               0             Own     85027
# 5535        53299.2               0               1            Rent     85012
#
# ...

# %%
# count of unique record
df['marital_status'].nunique()
# Out:
# 3

# %%
df.isnull()
# Out:
#        claim_number  age_of_driver  gender  marital_status  safety_rating  \
# 0             False          False   False           False          False
# 1             False          False   False           False          False
# 2             False          False   False           False          False
# 3             False          False   False           False          False
# 4             False          False   False           False          False
# ...             ...            ...     ...             ...            ...
# 11997         False          False   False           False          False
# 11998         False          False   False           False          False
# 11999         False          False   False           False          False
# 12000         False          False   False           False          False
# 12001         False          False   False           False          False
#
#        annual_income  high_education  address_change  property_status  \
# ...

# %%
df['age_of_driver'].mean()
# Out:
# np.float64(43.52516247292118)

# %%
df['age_of_driver'].value_counts()
# Out:
# age_of_driver
# 45     423
# 43     408
# 41     392
# 40     392
# 44     391
#       ...
# 180      1
# 278      1
# 249      1
# 101      1
# 100      1
# Name: count, Length: 81, dtype: int64

# %%
# display multiple column
df[['age_of_driver', 'gender', 'marital_status']]
# Out:
#        age_of_driver gender marital_status
# 0                 39      M              1
# 1                 33      M              1
# 2                 31      M              1
# 3                 53      F              1
# 4                 41      M              1
# ...              ...    ...            ...
# 11997             34      M              1
# 11998             65      F              1
# 11999             64      F              1
# 12000             34      F              1
# 12001             45      M              1
#
# [12002 rows x 3 columns]

# %%
df[['age_of_driver', 'gender', 'marital_status']].head(5)
# Out:
#    age_of_driver gender marital_status
# 0             39      M              1
# 1             33      M              1
# 2             31      M              1
# 3             53      F              1
# 4             41      M              1

# %%
df[df['policy deductible']>500]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 4           1140480             41      M              1             87
# 5           1244160             42      F              0             68
# ...             ...            ...    ...            ...            ...
# 11995     621665280             42      M              0             71
# 11996     621706752             31      F              1             70
# 11997     621727488             34      M              1             88
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
# TASK 2

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# claim_number          0
# age_of_driver         0
# gender                0
# marital_status        0
# safety_rating         0
# annual_income         0
# high_education        0
# address_change        0
# property_status       0
# zip_code              0
# claim_date            0
# claim_day_of_week     0
# accident_site         0
# past_num_of_claims    0
# witness_present       0
# liab_prct             0
# channel               0
# police_report         0
# age_of_vehicle        0
# vehicle_category      0
# vehicle_price         0
# vehicle_color         0
# total_claim           0
# injury_claim          0
# policy deductible     0
# annual premium        0
# days open             0
# form defects          0
# fraud reported        8
# dtype: int64

# %%
# Fill missing values with the most frequent value (mode)
mod = df["fraud reported"].mode()[0]
df["fraud reported"] = df["fraud reported"].fillna(mod)

# %%
print(df.isnull().sum())
# Out:
# claim_number          0
# age_of_driver         0
# gender                0
# marital_status        0
# safety_rating         0
# annual_income         0
# high_education        0
# address_change        0
# property_status       0
# zip_code              0
# claim_date            0
# claim_day_of_week     0
# accident_site         0
# past_num_of_claims    0
# witness_present       0
# liab_prct             0
# channel               0
# police_report         0
# age_of_vehicle        0
# vehicle_category      0
# vehicle_price         0
# vehicle_color         0
# total_claim           0
# injury_claim          0
# policy deductible     0
# annual premium        0
# days open             0
# form defects          0
# fraud reported        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# CSV file does not contain duplicate rows
print("Duplicate rows before removing:", df.duplicated().sum())
df = df.drop_duplicates()
print("Duplicate rows after removing:", df.duplicated().sum())
# Out:
# Duplicate rows before removing: 0
# Duplicate rows after removing: 0

# %%
df.dtypes
# Out:
# claim_number            int64
# age_of_driver           int64
# gender                 object
# marital_status         object
# safety_rating           int64
# annual_income         float64
# high_education          int64
# address_change          int64
# property_status        object
# zip_code                int64
# claim_date             object
# claim_day_of_week      object
# accident_site          object
# past_num_of_claims      int64
# witness_present        object
# liab_prct               int64
# channel                object
# police_report           int64
# age_of_vehicle         object
# vehicle_category       object
# vehicle_price         float64
# vehicle_color          object
# total_claim           float64
# injury_claim           object
# policy deductible       int64
# annual premium        float64
# days open             float64
# form defects            int64
# fraud reported         object
# dtype: object

# %%
print(df["claim_date"].head(10))
# Out:
# 0    08-12-2023
# 1    10/18/2024
# 2    12/23/2023
# 3     2/25/2024
# 4    09-04-2024
# 5     5/26/2024
# 6     5/23/2024
# 7     8/31/2023
# 8     9/27/2024
# 9     7/24/2023
# Name: claim_date, dtype: object

# %%
# 1. Fix Incorrect Data Types

# Convert claim_date to datetime
df['claim_date'] = pd.to_datetime(df['claim_date'], errors='coerce')

# Convert annual_income to numeric
df['annual_income'] = pd.to_numeric(df['annual_income'], errors='coerce')

# Convert age_of_vehicle to numeric
df['age_of_vehicle'] = pd.to_numeric(df['age_of_vehicle'], errors='coerce')

# Convert injury_claim to numeric
df['injury_claim'] = pd.to_numeric(df['injury_claim'], errors='coerce')

print(df.dtypes)
# Out:
# claim_number                   int64
# age_of_driver                  int64
# gender                        object
# marital_status                object
# safety_rating                  int64
# annual_income                float64
# high_education                 int64
# address_change                 int64
# property_status               object
# zip_code                       int64
# claim_date            datetime64[ns]
# claim_day_of_week             object
# accident_site                 object
# past_num_of_claims             int64
# witness_present               object
# liab_prct                      int64
# channel                       object
# police_report                  int64
# age_of_vehicle               float64
# vehicle_category              object
# vehicle_price                float64
# vehicle_color                 object
# total_claim                  float64
# injury_claim                 float64
# policy deductible              int64
# ...

# %%
Q1 = df['total_claim'].quantile(0.25)
Q3 = df['total_claim'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['total_claim'] >= lower) & (df['total_claim'] <= upper)]

print("Outliers removed successfully!")
print("New Shape:", df.shape)
# Out:
# Outliers removed successfully!
# New Shape: (11676, 29)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,4))

plt.hist(df['age_of_driver'], bins=10, edgecolor='black')

plt.title('Histogram of Age of Driver')
plt.xlabel('Age of Driver')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.boxplot(df['form defects'].dropna())

plt.title('Box Plot of Form Defects')
plt.ylabel('Form Defects')

plt.show()

# %%
df['gender'].value_counts().plot(kind='bar')

plt.title('Bar Plot of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
df['gender'].value_counts().plot(
    kind='pie',
    autopct='%1.2f%%'
)

plt.title('Pie Chart of Gender')
plt.ylabel('')

plt.show()

# %%
import seaborn as sns

sns.countplot(x='gender', data=df)

plt.title('Count Plot of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
# Encode Categorical Columns

categorical_cols = df.select_dtypes(include='object').columns

df_encoded = pd.get_dummies(
    df,
    columns=categorical_cols,
    drop_first=True
)

print("Encoded Shape:", df_encoded.shape)
# Out:
# Encoded Shape: (11676, 45)

# %%
# Scale Numeric Columns
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numeric_cols = df_encoded.select_dtypes(include=['int64', 'float64']).columns

df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

print(df_encoded.head())
# Out:
#    claim_number  age_of_driver  safety_rating  annual_income  high_education  \
# 0      0.000367       0.077220       0.724490       0.213776             1.0
# 1      0.000133       0.054054       0.714286       0.124048             0.0
# 2      0.001267       0.046332       0.755102       0.317951             1.0
# 3      0.001300       0.131274       0.928571       0.272787             0.0
# 4      0.001534       0.084942       0.867347       0.216904             1.0
#
#    address_change  zip_code claim_date  past_num_of_claims  liab_prct  ...  \
# 0             0.0  0.588226 2023-08-12                 0.0       0.25  ...
# 1             1.0  0.587732        NaT                 0.0       0.45  ...
# 2             1.0  0.176545        NaT                 0.0       1.00  ...
# 3             1.0  0.999342        NaT                 0.0       1.00  ...
# 4             0.0  0.940799 2024-09-04                 0.0       0.25  ...
#
# ...

# %%
# Clean Messy Column Names

df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_', regex=False)
)

print(df.columns.tolist())
# Out:
# ['claim_number', 'age_of_driver', 'gender', 'marital_status', 'safety_rating', 'annual_income', 'high_education', 'address_change', 'property_status', 'zip_code', 'claim_date', 'claim_day_of_week', 'accident_site', 'past_num_of_claims', 'witness_present', 'liab_prct', 'channel', 'police_report', 'age_of_vehicle', 'vehicle_category', 'vehicle_price', 'vehicle_color', 'total_claim', 'injury_claim', 'policy_deductible', 'annual_premium', 'days_open', 'form_defects', 'fraud_reported']
